# %% [markdown]
# <a href="https://colab.research.google.com/github/panzershracker/Recomender-systems/blob/master/HW_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #В качестве домашнего задания ответьте на следующие вопросы:
# 1. В чем принципиальные отличия item-item рекомендаций от ALS?
# 2. Приведите 3 примера весов user-item матрицы для задачи рекоммендаций товаров
# 3. Какие ограничения есть у ALS? (Тип информации, линейность/нелинейность факторов и т д)
#
# P.S. Задания на программирование будут выкладываться каждую неделю после занятия в четверг

# %% [markdown]
# #1:
# - В том что item-item - алгоритм на основе KNN, а ALS только оптимизатор, на основе градиентного спуска.
# - В item-item, если я верно понял, пересчет модели проходит ночью (как правило), а на следующий день юзеру показывают одни и те же рекомендации, вне зависимости что он купил в этот день, и так до следующего ночного пересчета модели. В ALS - при фиксации эмбедингов товара возможно в реальном времени обновлять эмбединги юзеров.
# -Так же item-item рекомендации имеют бОльшую сложность чем ALS. На большиъ наборах данных ALS может во много раз превосходить по скорости item-item рекомендации.
#
# #!
# Скорее всего есть и другие важные различия, но пока я "плаваю" в теме и не все до конца понимаю.
#
# #2:
# Если я верно понял, то это значения таблицы которые обозначают:
# - кол-во покупок
# - факт совершения покупки юзером данного товара
# - общая выручка по покупке товара конкретным юзером
#
#
# #3:
#
# - Учитывается только сила взаимодействия юзера с товаром. Никакие признаки не учитываются.
# - предсказания нельзя интерпретировать как вероятность
# - Не понял что имеется ввиду под "тип информации", но возможно имеются ввиду латентные факторы, которые не имеют понятного нам смысла и никак не интерпретируются.
#
# #!
#
#  Уже и так и сяк просматриваю вебинар но не знаю что еще написать по данному пункту. Надеюсь в вебинаре будут даны ответы )
